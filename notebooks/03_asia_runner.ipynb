# %% [markdown]
# # **Asia Runner**

# %% [markdown]
# ## **1. Project Setup**

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()

if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: c:\candle-fetcher

# %% [markdown]
# ## **2. Imports**

# %%
from src.pipeline import run_asia_pipeline, print_pipeline_result
from src.mt5_fetcher import MT5FetchConfig, fetch_raw_candles, print_fetch_result

# %% [markdown]
# ## **3. Settings**

# %%
# ---------------------------------------------------------------------------
# Asia Runner Settings
# ---------------------------------------------------------------------------

SYMBOL = "US100.cash"
TIMEFRAME = "1m"

START_DATE = "2021-01-01"
END_DATE = "2021-12-31"

# Optional filters.
# Leave as None if you do not want to use them.
YEARS = None
MONTHS = None
WEEKS = None
DAYS = None
WEEKDAYS = None

OUTPUT_SUFFIX = None
OUTPUT_NAME = None

# ---------------------------------------------------------------------------
# MT5 Fetch Settings
# ---------------------------------------------------------------------------

FETCH_FROM_MT5 = True

RANGE_NAME = "asia_range"

FETCH_START_DATE = START_DATE
FETCH_END_DATE = END_DATE

CHUNK_DAYS = 31

# Dates are interpreted in this timezone before converting to UTC.
DATE_TIMEZONE_NAME = "Asia/Tokyo"

# %% [markdown]
# ## **4. Fetch Raw Candles From MT5**

# %%
input_pattern = "*.csv"

if FETCH_FROM_MT5:
    fetch_config = MT5FetchConfig(
        symbol=SYMBOL,
        timeframe=TIMEFRAME,
        range_name=RANGE_NAME,
        start_date=FETCH_START_DATE,
        end_date=FETCH_END_DATE,
        chunk_days=CHUNK_DAYS,
        date_timezone_name=DATE_TIMEZONE_NAME,
    )

    fetch_result = fetch_raw_candles(fetch_config)
    print_fetch_result(fetch_result)

    # Only process the CSV that was just fetched.
    input_pattern = fetch_result["filename"]

else:
    print("Skipping MT5 fetch. Loading existing CSV files from data/raw/.")
# Out:
# Fetching chunk: 2020-12-31 15:00 -> 2021-01-31 15:00 UTC
# Fetching chunk: 2021-01-31 15:00 -> 2021-03-03 15:00 UTC
# Fetching chunk: 2021-03-03 15:00 -> 2021-04-03 15:00 UTC
# Fetching chunk: 2021-04-03 15:00 -> 2021-05-04 15:00 UTC
# Fetching chunk: 2021-05-04 15:00 -> 2021-06-04 15:00 UTC
# Fetching chunk: 2021-06-04 15:00 -> 2021-07-05 15:00 UTC
# Fetching chunk: 2021-07-05 15:00 -> 2021-08-05 15:00 UTC
# Fetching chunk: 2021-08-05 15:00 -> 2021-09-05 15:00 UTC
# Fetching chunk: 2021-09-05 15:00 -> 2021-10-06 15:00 UTC
# Fetching chunk: 2021-10-06 15:00 -> 2021-11-06 15:00 UTC
# Fetching chunk: 2021-11-06 15:00 -> 2021-12-07 15:00 UTC
# Fetching chunk: 2021-12-07 15:00 -> 2021-12-31 15:00 UTC
# MT5 raw candle fetch complete
# Symbol: US100.cash
# Timeframe: M1
# Rows saved: 108,819
# First datetime UTC: 2021-01-04 00:00:00+00:00
# Last datetime UTC: 2021-12-31 14:59:00+00:00
# Filename: us100_cash_M1_raw_asia_range_2021-01-01_to_2021-12-31.csv
# Path: C:\candle-fetcher\data\raw\us100_cash_M1_raw_asia_range_2021-01-01_to_2021-12-31.csv

# %% [markdown]
# ## **5. Run Asia Filter**

# %%
result = run_asia_pipeline(
    start_date=START_DATE,
    end_date=END_DATE,
    years=YEARS,
    months=MONTHS,
    weeks=WEEKS,
    days=DAYS,
    weekdays=WEEKDAYS,
    symbol=SYMBOL,
    timeframe=TIMEFRAME,
    input_pattern=input_pattern,
    output_suffix=OUTPUT_SUFFIX,
    output_name=OUTPUT_NAME,
)

print_pipeline_result(result)
# Out:
# Starting candle pipeline
# Asia: 09:00 to 12:00 (Asia/Tokyo)
# Loading: C:\candle-fetcher\data\raw\us100_cash_M1_raw_asia_range_2021-01-01_to_2021-12-31.csv
# Raw rows loaded: 108,819
# Raw first datetime: 2021-01-04 00:00:00+00:00
# Raw last datetime: 2021-12-31 14:59:00+00:00
# Rows after date filters: 108,819
# Rows after session filter: 9,251
# Export complete
# Session: asia
# Rows saved: 9,251
# Filename: us100_cash_M1_asia_2021_01_01_to_2021_12_31.csv
# Path: C:\candle-fetcher\data\processed\asia\us100_cash_M1_asia_2021_01_01_to_2021_12_31.csv
# Pipeline result
# Session: asia
# Description: Asia: 09:00 to 12:00 (Asia/Tokyo)
# Raw rows: 108,819
# Date-filtered rows: 108,819
# Final rows: 9,251
# First datetime: 2021-01-04 00:00:00+00:00
# Last datetime: 2021-12-31 02:59:00+00:00
# Saved to: C:\candle-fetcher\data\processed\asia\us100_cash_M1_asia_2021_01_01_to_2021_12_31.csv

# %% [markdown]
# ## **6. View Data**

# %%
df = result["data"]
df.head()
# Out:
#                    datetime      open      high       low     close  \
# 0 2021-01-04 00:00:00+00:00  12911.10  12973.00  12535.75  12701.75
# 1 2021-01-05 00:00:00+00:00  12698.85  12821.20  12624.25  12816.95
# 2 2021-01-06 00:00:00+00:00  12816.00  12856.65  12503.15  12672.35
# 3 2021-01-07 00:00:00+00:00  12671.85  12970.85  12660.50  12939.85
# 4 2021-01-08 00:00:00+00:00  12944.10  13138.85  12933.00  13137.10
#
#    tick_volume  spread  real_volume session_name
# 0       278601       0            0         asia
# 1       240276       0            0         asia
# 2       385766       0            0         asia
# 3       230864       0            0         asia
# 4       249305       0            0         asia

# %% [markdown]
# ## **7. Check Size**

# %%
df.shape
# Out:
# (9251, 9)
